# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import random
# %matplotlib inline
import PIL
print(PIL.__version__)
from matplotlib import image
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 9.5.0

# %%
IMG_WIDTH=200
IMG_HEIGHT=200
img_folder='/kaggle/input/cat-and-dog/training_set/training_set/'

def create_dataset(img_folder):
   
    img_data_array=[]
    class_name=[]
    
    for dir1 in os.listdir(img_folder):
        print("Collecting images for: ",dir1)
        for file in os.listdir(os.path.join(img_folder, dir1)):
       
            image_path= os.path.join(img_folder, dir1,  file)
            image= cv2.imread( image_path, cv2.COLOR_BGR2RGB)
            try:
                image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            except:
                break
            image=np.array(image)
            image = image.astype('float32')
            image /= 255 
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array, class_name
# extract the image array and class name
img_data, class_name =create_dataset('/kaggle/input/cat-and-dog/training_set/training_set/')
# Out:
# Collecting images for:  dogs
# Collecting images for:  cats

# %%
def dog_cat_mapping(a):
    if a == "dogs":
        return 1
    else:
        return 0 

class_name = list(map(dog_cat_mapping,class_name))
class_name = np.array(class_name)
print(class_name)
# Out:
# [1 1 1 ... 0 0 0]

# %%
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

# %%
img_data = np.array(img_data)
img_data = img_data.reshape((img_data.shape[0],-1))
input_shape = img_data.shape[1:]
input_shape
class_name.shape
# Out:
# (1954,)

# %%
from tensorflow.keras.optimizers import Adam
def build_model():
    model=Sequential()
    model.add(Dense(35,input_shape=input_shape,activation ="relu"))
    model.add(Dense(1,activation='sigmoid'))
    return model
              
model  = build_model()
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,loss="binary_crossentropy",metrics=['accuracy'])
model.fit(x = img_data, y= class_name, epochs=35)
# Out:
# Epoch 1/35
# 62/62 [==============================] - 2s 9ms/step - loss: 6.1120 - accuracy: 0.5220
# Epoch 2/35
# 62/62 [==============================] - 1s 8ms/step - loss: 2.2729 - accuracy: 0.5522
# Epoch 3/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.4604 - accuracy: 0.5722
# Epoch 4/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.8725 - accuracy: 0.5691
# Epoch 5/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.2241 - accuracy: 0.5983
# Epoch 6/35
# 62/62 [==============================] - 1s 8ms/step - loss: 2.6067 - accuracy: 0.5783
# Epoch 7/35
# 62/62 [==============================] - 1s 9ms/step - loss: 1.6127 - accuracy: 0.6233
# Epoch 8/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.1667 - accuracy: 0.6397
# Epoch 9/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.8303 - accuracy: 0.6755
# Epoch 10/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.4667 - accuracy: 0.6177
# Epoch 11/35
# 62/62 [==============================] - 1s 9ms/step - loss: 1.6939 - accuracy: 0.6377
# Epoch 12/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.8705 - accuracy: 0.7057
# Epoch 13/35
# 62/62 [==============================] - 1s 9ms/step - loss: 1.4579 - accuracy: 0.6469
# Epoch 14/35
# 62/62 [==============================] - 1s 8ms/step - loss: 4.7802 - accuracy: 0.5558
# Epoch 15/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.6483 - accuracy: 0.7088
# Epoch 16/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.5534 - accuracy: 0.7456
# Epoch 17/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.6615 - accuracy: 0.7124
# Epoch 18/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.6079 - accuracy: 0.7298
# Epoch 19/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.4777 - accuracy: 0.6269
# Epoch 20/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.6347 - accuracy: 0.7242
# Epoch 21/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.7117 - accuracy: 0.6786
# Epoch 22/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.8165 - accuracy: 0.6853
# Epoch 23/35
# 62/62 [==============================] - 1s 8ms/step - loss: 1.0745 - accuracy: 0.6709
# Epoch 24/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.6089 - accuracy: 0.7329
# Epoch 25/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.7775 - accuracy: 0.7139
# Epoch 26/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.5295 - accuracy: 0.7549
# Epoch 27/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.5217 - accuracy: 0.7692
# Epoch 28/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.5157 - accuracy: 0.7707
# Epoch 29/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.3982 - accuracy: 0.8173
# Epoch 30/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.8153 - accuracy: 0.6888
# Epoch 31/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.5984 - accuracy: 0.7313
# Epoch 32/35
# 62/62 [==============================] - 1s 9ms/step - loss: 1.1253 - accuracy: 0.6412
# Epoch 33/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.5204 - accuracy: 0.7738
# Epoch 34/35
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3890 - accuracy: 0.8265
# Epoch 35/35
# 62/62 [==============================] - 1s 8ms/step - loss: 0.4330 - accuracy: 0.8291

# %%
from tensorflow.keras.optimizers import Adam
def build_model():
    model=Sequential()
    model.add(Dense(35,input_shape=input_shape,activation ="relu"))
#     model.add(Dropout(0.5))
#     model.add(Dense(64,activation ="relu"))
#     model.add(Dense(128,activation ="relu"))
#     model.add(Dense(256,activation ="relu"))
#     model.add(Dense(256*2,activation ="relu"))
#     model.add(Dense(256,activation ="relu"))
    model.add(Dense(1,activation='sigmoid'))
    return model
              
model  = build_model()
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,loss="binary_crossentropy",metrics=['accuracy'])
model.fit(x = img_data, y= class_name, epochs=35)
